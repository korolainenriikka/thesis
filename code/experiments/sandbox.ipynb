# %%
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
from PIL import Image
import os
import mlflow
import numpy as np
import pandas as pd
from torchvision.io import read_image
from torch.utils.data import Dataset

import torch
import torchvision

from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch import nn

# %%
# load model and labels
MAX_NEW_TOKENS = 40
processor = TrOCRProcessor.from_pretrained('microsoft/trocr-large-handwritten')
model = VisionEncoderDecoderModel.from_pretrained('microsoft/trocr-large-handwritten')
path = '/home/riikoro/fossil_data/tooth_samples/v1'
label_filename = 'labels.txt'
with open(os.path.join(path, label_filename)) as label_file:
    labels = label_file.read().splitlines()

model.config
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-large-handwritten and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# VisionEncoderDecoderConfig {
#   "_name_or_path": "microsoft/trocr-large-handwritten",
#   "architectures": [
#     "VisionEncoderDecoderModel"
#   ],
#   "decoder": {
#     "_name_or_path": "",
#     "activation_dropout": 0.0,
#     "activation_function": "gelu",
#     "add_cross_attention": true,
#     "architectures": null,
#     "attention_dropout": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": 0,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": 1024,
#     "d_model": 1024,
#     "decoder_attention_heads": 16,
#     "decoder_ffn_dim": 4096,
#     "decoder_layerdrop": 0.0,
#     "decoder_layers": 12,
#     "decoder_start_token_id": 2,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 2,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "init_std": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layernorm_embedding": true,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 512,
#     "min_length": 0,
#     "model_type": "trocr",
#     "no_repeat_ngram_size": 0,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 1,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": false,
#     "use_learned_position_embeddings": true,
#     "vocab_size": 50265
#   },
#   "encoder": {
#     "_name_or_path": "",
#     "add_cross_attention": false,
#     "architectures": null,
#     "attention_probs_dropout_prob": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "encoder_stride": 16,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.0,
#     "hidden_size": 1024,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "image_size": 384,
#     "initializer_range": 0.02,
#     "intermediate_size": 4096,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-12,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_type": "vit",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 16,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_channels": 3,
#     "num_hidden_layers": 24,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": null,
#     "patch_size": 16,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "qkv_bias": false,
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false
#   },
#   "is_encoder_decoder": true,
#   "model_type": "vision-encoder-decoder",
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.33.2"
# }

# %%
def evaluate(generated, label):
    """
    Generate word counts required for precision and recall

    Args:
        generated: sentence generated with OCR
        label:     correct text in the image

    Returns:
        int: count of correct words in the generated sequence (correct word in wrong position is wrong)
        int: count of words in the generated sequence
        int: count of words in the label
    """
    generated_words = generated.split(' ')
    label_words = label.split(' ')
    correct_words = 0

    generated_word_count = len(generated_words)
    label_word_count = len(label_words)
    for i in range(generated_word_count):
        if i >= label_word_count:
            break
        if label_words[i] == generated_words[i]:
            correct_words += 1

    return correct_words, generated_word_count, label_word_count

# %%
total_correct = 0
total_generated = 0
total_label_words = 0

# empty arrays to store model outputs
predicted_labels = [''] * len(labels)
total_image_folder_size = len(os.listdir(path))
img_no = 1

for file in os.listdir(path):
    if not file.endswith('.png'):
        continue
    img_path = os.path.join(path, file)
    img_no = int(file.split('.')[0])

    with Image.open(img_path) as image:
        pixel_values = processor(images=image, return_tensors="pt").pixel_values

        generated_ids = model.generate(pixel_values, max_new_tokens=MAX_NEW_TOKENS)
        generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
        predicted_labels[img_no] = generated_text
        
        correct_label = labels[img_no]
        print(f'--- reading dental marking from {file} ---')
        print(f'generated: {generated_text}')
        print(f'correct: {correct_label}')
        print(f'read: {img_no}/{total_image_folder_size}')
        print
        correct_word_count, generated_word_count, label_word_count = evaluate(generated_text, correct_label)

        total_correct += correct_word_count
        total_generated += generated_word_count
        total_label_words += label_word_count

        img_no += 1
# Out:
# --- reading dental marking from 9.png ---
# Left mandible frog with broken Px, M, and
# Left mandible frag with broken P4̌, M1̌ and
# 5
# 8
# 8
# --- reading dental marking from 35.png ---
# A- Proximal # distal end right femur
# Proximal & distal end right femur
# 0
# 7
# 6
# --- reading dental marking from 10.png ---
# Isolated.
# Isolated
# 0
# 1
# 1
# --- reading dental marking from 44.png ---
# As Lktibia.
# A= Lt tibia
# 0
# 2
# 3
# --- reading dental marking from 34.png ---
# proximal.
# proximal
# 0
# 1
# 1
# --- reading dental marking from 58.png ---
# As left mandibular corpus with teeth " : " 3
# A= Left mandibular corpus with teeth M1̄̌-M3̄̌
# 4
# 10
# 7
# --- reading dental marking from 13.png ---
# Shalt lacking desstal A proximal ends
# Shaft lacking distal & proximal ends
# 3
# 6
# 6
# --- reading dental marking from 56.png ---
# isolated # RC. RM3, HM3, WHO, HM2.
# Isolated L.C̱, RM3̱̂, LM3̱̂, LM2̱̂, LM3̌
# 0
# 7
# 6
# --- reading dental marking from 19.png ---
# 10kote.
# lokote
# 0
# 1
# 1
# --- reading dental marking from 21.png ---
# llms.
# M3̂
# 0
# 1
# 1
# --- reading dental marking from 65.png ---
# Ai prox.
# A: prox
# 0
# 2
# 2
# --- reading dental marking from 17.png ---
# Aitupper premolas Uninterrupted. L.S. MDR
# A: 4 upper premolar (P3̱̌) unerrupted. L. mbs
# 0
# 5
# 8
# --- reading dental marking from 37.png ---
# Left mandible frog with M3
# Left mandible frag with M3̌
# 3
# 5
# 5
# --- reading dental marking from 40.png ---
# Right mandible tray with broken M.,a ( Just
# Right mandible frag with broken M1̌-̌3̌
# 4
# 8
# 6
# --- reading dental marking from 60.png ---
# max from with 2.7.1.3.
# max frag with 1/2M2̂-M3̂
# 2
# 4
# 4
# --- reading dental marking from 66.png ---
# R mandible frog with roots Pz-M3
# R mandible frag with roots P3̌-M3̌
# 4
# 6
# 6
# --- reading dental marking from 32.png ---
# A : distal end left femur
# A = distal end left femur
# 5
# 6
# 6
# --- reading dental marking from 46.png ---
# Maudible frog with corrupting LIT2, "LITz #
# Mandible frag with errupting LM2̌, LM3̌ &
# 1
# 7
# 7
# --- reading dental marking from 8.png ---
# Isolated RC, RP. RN.
# Isolated RC̱, RP4̱̂, RM
# 1
# 4
# 4
# --- reading dental marking from 54.png ---
# B. R.13 at tooth fraas (1/2 )
# B= RM3̂ & tooth frags (12)
# 1
# 7
# 6
# --- reading dental marking from 57.png ---
# Left max. frag with P.M.3
# Left max.frag with P4̱̂M3̂
# 1
# 5
# 4
# --- reading dental marking from 18.png ---
# frag. right when proximal erd.wt shaft-
# frag. right ulna proximal erd. wt. shaft.
# 3
# 6
# 7
# --- reading dental marking from 64.png ---
# Proximal and right femwr ( greater trochamber
# Proximal end right femur (goeates trochauter
# 2
# 7
# 6
# --- reading dental marking from 28.png ---
# In maudible frog with M.3-3.
# L mandible frag with M1̌-̌3̌
# 1
# 5
# 5
# --- reading dental marking from 59.png ---
# R. Croot.
# R.C̄root
# 0
# 2
# 1
# --- reading dental marking from 24.png ---
# RP4
# Rt P4̄̌
# 0
# 1
# 2
# --- reading dental marking from 48.png ---
# isolated.
# Isolated
# 0
# 1
# 1
# --- reading dental marking from 3.png ---
# Litz
# LM2̌
# 0
# 1
# 1
# --- reading dental marking from 31.png ---
# helk vlua lacking dostal epiplysis.
# Left ulna lacking distal epiphysis
# 1
# 5
# 5
# --- reading dental marking from 23.png ---
# Mandible lacking left ascending ramps :
# Mandible lacking left ascending ramus;
# 4
# 6
# 5
# --- reading dental marking from 43.png ---
# frontor ofrag.
# frontal frag
# 0
# 2
# 2
# --- reading dental marking from 63.png ---
# Distal left numerous frog.
# Distal left humerus frag
# 2
# 4
# 4
# --- reading dental marking from 26.png ---
# Broken molar! (M ).
# Broken molar !(M̱)
# 1
# 4
# 3
# --- reading dental marking from 33.png ---
# Rkir.
# Rt.
# 0
# 1
# 1
# --- reading dental marking from 2.png ---
# L2, # 1 tooth frags #
# LI2̌, RM̱2̌ & tooth frags (8)
# 2
# 6
# 6
# --- reading dental marking from 12.png ---
# Snap. We Izalvedus, Crossot # (3-ME
# frag wi I2̄̌ alveolus, croots P3̄̌-M2̄̌
# 0
# 6
# 6
# --- reading dental marking from 16.png ---
# L mandible frag with roots M.s.
# L mandible frag with roots M2̌-̌3̌
# 5
# 6
# 6
# --- reading dental marking from 52.png ---
# # Edenulous frag.
# Lt. Edentulous frag
# 0
# 3
# 3
# --- reading dental marking from 6.png ---
# authorior.
# anterior
# 0
# 1
# 1
# --- reading dental marking from 5.png ---
# Isolated.
# Isolated
# 0
# 1
# 1
# --- reading dental marking from 15.png ---
# proximal frag. right ulna
# proximal frag. right ulna
# 4
# 4
# 4
# --- reading dental marking from 45.png ---
# to those.
# lokote
# 0
# 2
# 1
# --- reading dental marking from 20.png ---
# A :frey left mandible corpus with 1/3 roots
# A = frag left mandible corpus with M3̌ roots
# 1
# 8
# 9
# --- reading dental marking from 11.png ---
# 93.
# M3̂
# 0
# 1
# 1
# --- reading dental marking from 39.png ---
# L. M.3.
# LM3̌
# 0
# 2
# 1
# --- reading dental marking from 27.png ---
# I solated RM2, Rolls, broken him's ( Olde-mor
# Isolated RM2̌, RM3̌, broken LM3̌
# 0
# 8
# 5
# --- reading dental marking from 29.png ---
# Proximal part right femur
# Proximal part right femur
# 4
# 4
# 4
# --- reading dental marking from 42.png ---
# A : R mandible with E-M,
# A= R mandible with C̄-M1̌
# 0
# 6
# 5
# --- reading dental marking from 7.png ---
# memory.
# man
# 0
# 1
# 1
# --- reading dental marking from 0.png ---
# Dustal half left numerous with broken medial
# Distal half left humerus with broken medial
# 5
# 7
# 7
# --- reading dental marking from 51.png ---
# A : shaft L humeros frog.
# A = shaft L humerus frag.
# 3
# 6
# 6
# --- reading dental marking from 50.png ---
# Distal half right numerous
# Distal half right humerus
# 3
# 4
# 4
# --- reading dental marking from 55.png ---
# Isolatek LP# R.M. R.M.L.M.
# Isolated L.P4̌; R.M1̌; R.M2̌; L.M2̌;
# 0
# 4
# 5
# --- reading dental marking from 47.png ---
# isolated LP, hly, broken him, ( XV.
# Isolated LP3̌, LP4̌, broken LM2̌
# 1
# 7
# 5
# --- reading dental marking from 30.png ---
# A :K mand-ble with Mrs.s most
# A= R mandible with M2̄̌-̌3̄̌ M1̌ root
# 1
# 6
# 7
# --- reading dental marking from 14.png ---
# Frag left mandibular corpus lacking teeth
# Frag left mandibular corpus lacking teeth
# 6
# 6
# 6
# --- reading dental marking from 41.png ---
# Isoated RM, R.M. 4.2. 4.3.2.2.2LN.
# Isolated LM1̌, RM3̌, LM3̌, R1/2LM1̌
# 0
# 5
# 5
# --- reading dental marking from 62.png ---
# L calcaneum
# L calcaneum
# 2
# 2
# 2
# --- reading dental marking from 25.png ---
# LM '
# LM1̂
# 0
# 2
# 1
# --- reading dental marking from 22.png ---
# Romandible drag with P4-M2
# RT.mandible frag with P4̌-M2̌
# 1
# 4
# 4
# --- reading dental marking from 49.png ---
# K mandible A partial skeleton ( P.T.O )
# R mandible & partial skeleton (P.T.O)
# 3
# 8
# 6
# --- reading dental marking from 36.png ---
# Right numerous lacking prox. epiplysis
# Right humerus lacking prox. epiphysis
# 3
# 5
# 5
# --- reading dental marking from 53.png ---
# L mandible frag with Mg.3
# L mandible frag with M2̌-̌3̌
# 4
# 5
# 5
# --- reading dental marking from 61.png ---
# prox R radius.
# prox R radius
# 2
# 3
# 3
# --- reading dental marking from 4.png ---
# right maxilla with frag of zygomatic and
# right maxilla with frag of zygomatic and
# 7
# 7
# 7
# --- reading dental marking from 38.png ---
# Litz
# LM2̱̂
# 0
# 1
# 1
# --- reading dental marking from 1.png ---
# Isolated.
# Isolated
# 0
# 1
# 1

# %%
precision = total_correct / total_generated
recall = total_correct / total_label_words
f1 = (2*precision*recall)/(precision+recall)

# %%
print(precision)
print(recall)
print(f1)
# Out:
# 0.3620689655172414
# 0.38181818181818183
# 0.3716814159292036

# %% [markdown]
# ### OCR performance with difflib SequenceMatcher

# %%
print(labels)
print(predicted_labels)
# Out:
# ['Distal half left humerus with broken medial', 'Isolated', 'LI2̌, RM̱2̌ & tooth frags (8)', 'LM2̌', 'right maxilla with frag of zygomatic and', 'Isolated', 'anterior', 'man', 'Isolated RC̱, RP4̱̂, RM', 'Left mandible frag with broken P4̌, M1̌ and', 'Isolated', 'M3̂', 'frag wi I2̄̌ alveolus, croots P3̄̌-M2̄̌', 'Shaft lacking distal & proximal ends', 'Frag left mandibular corpus lacking teeth', 'proximal frag. right ulna', 'L mandible frag with roots M2̌-̌3̌', 'A: 4 upper premolar (P3̱̌) unerrupted. L. mbs', 'frag. right ulna proximal erd. wt. shaft.', 'lokote', 'A = frag left mandible corpus with M3̌ roots', 'M3̂', 'RT.mandible frag with P4̌-M2̌', 'Mandible lacking left ascending ramus;', 'Rt P4̄̌', 'LM1̂', 'Broken molar !(M̱)', 'Isolated RM2̌, RM3̌, broken LM3̌', 'L mandible frag with M1̌-̌3̌', 'Proximal part right femur', 'A= R mandible with M2̄̌-̌3̄̌ M1̌ root', 'Left ulna lacking distal epiphysis', 'A = distal end left femur', 'Rt.', 'proximal', 'Proximal & distal end right femur', 'Right humerus lacking prox. epiphysis', 'Left mandible frag with M3̌', 'LM2̱̂', 'LM3̌', 'Right mandible frag with broken M1̌-̌3̌', 'Isolated LM1̌, RM3̌, LM3̌, R1/2LM1̌', 'A= R mandible with C̄-M1̌', 'frontal frag', 'A= Lt tibia', 'lokote', 'Mandible frag with errupting LM2̌, LM3̌ &', 'Isolated LP3̌, LP4̌, broken LM2̌', 'Isolated', 'R mandible & partial skeleton (P.T.O)', 'Distal half right humerus', 'A = shaft L humerus frag.', 'Lt. Edentulous frag', 'L mandible frag with M2̌-̌3̌', 'B= RM3̂ & tooth frags (12)', 'Isolated L.P4̌; R.M1̌; R.M2̌; L.M2̌;', 'Isolated L.C̱, RM3̱̂, LM3̱̂, LM2̱̂, LM3̌', 'Left max.frag with P4̱̂M3̂', 'A= Left mandibular corpus with teeth M1̄̌-M3̄̌', 'R.C̄root', 'max frag with 1/2M2̂-M3̂', 'prox R radius', 'L calcaneum', 'Distal left humerus frag', 'Proximal end right femur (goeates trochauter', 'A: prox', 'R mandible frag with roots P3̌-M3̌']
# ['Dustal half left numerous with broken medial', 'Isolated.', 'L2, # 1 tooth frags #', 'Litz', 'right maxilla with frag of zygomatic and', 'Isolated.', 'authorior.', 'memory.', 'Isolated RC, RP. RN.', 'Left mandible frog with broken Px, M, and', 'Isolated.', '93.', 'Snap. We Izalvedus, Crossot # (3-ME', 'Shalt lacking desstal A proximal ends', 'Frag left mandibular corpus lacking teeth', 'proximal frag. right ulna', 'L mandible frag with roots M.s.', 'Aitupper premolas Uninterrupted. L.S. MDR', 'frag. right when proximal erd.wt shaft-', '10kote.', 'A :frey left mandible corpus with 1/3 roots', 'llms.', 'Romandible drag with P4-M2', 'Mandible lacking left ascending ramps :', 'RP4', "LM '", 'Broken molar! (M ).', "I solated RM2, Rolls, broken him's ( Olde-mor", 'In maudible frog with M.3-3.', 'Proximal part right femur', 'A :K mand-ble with Mrs.s most', 'helk vlua lacking dostal epiplysis.', 'A : distal end left femur', 'Rkir.', 'proximal.', 'A- Proximal # distal end right femur', 'Right numerous lacking prox. epiplysis', 'Left mandible frog with M3', 'Litz', 'L. M.3.', 'Right mandible tray with broken M.,a ( Just', 'Isoated RM, R.M. 4.2. 4.3.2.2.2LN.', 'A : R mandible with E-M,', 'frontor ofrag.', 'As Lktibia.', 'to those.', 'Maudible frog with corrupting LIT2, "LITz #', 'isolated LP, hly, broken him, ( XV.', 'isolated.', 'K mandible A partial skeleton ( P.T.O )', 'Distal half right numerous', 'A : shaft L humeros frog.', '# Edenulous frag.', 'L mandible frag with Mg.3', 'B. R.13 at tooth fraas (1/2 )', 'Isolatek LP# R.M. R.M.L.M.', 'isolated # RC. RM3, HM3, WHO, HM2.', 'Left max. frag with P.M.3', 'As left mandibular corpus with teeth " : " 3', 'R. Croot.', 'max from with 2.7.1.3.', 'prox R radius.', 'L calcaneum', 'Distal left numerous frog.', 'Proximal and right femwr ( greater trochamber', 'Ai prox.', 'R mandible frog with roots Pz-M3']

# %%
from difflib import SequenceMatcher
def similarity(x, y):
    return SequenceMatcher(None, x, y).ratio()

def sequence_matcher_score(labels, predicted_labels):
    similarities = np.array([0.0] * len(labels))
    for i in range(len(labels)):
        similarities[i] = similarity(predicted_labels[i], labels[i])
    return np.mean(similarities)

sequence_score = sequence_matcher_score(labels, predicted_labels)
print(f"Sequence matcher score, baseline: {sequence_score}")
# Out:
# Sequence matcher score, baseline: 0.7528348747647537

# %% [markdown]
# ### MLflow logging

# %%
# %env MLFLOW_TRACKING_URI=sqlite:///mlruns.db
mlflow.set_experiment("Dental element OCR")

params = {
    'data_v': 1,
    'max_new_tokens': MAX_NEW_TOKENS
}

# Start an MLflow run
with mlflow.start_run():
    # Log the hyperparameters
    mlflow.log_params(params)

    # Log the loss metric
    mlflow.log_metric("precision", precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1", f1)
    mlflow.log_metric("sequence matcher score", sequence_score)

    # Set a tag that we can use to remind ourselves what this run was for
    mlflow.set_tag("info", "Untuned TrOCR-handwritten-large")
# Out:
# env: MLFLOW_TRACKING_URI=sqlite:///mlruns.db

# %% [markdown]
# ## Train on V1 data & check how metrics change
#
# todo:
# - uniformize train image sizes
# - perform training (try allowing any weight change & only last layer changes)
# - log metrics to mlflow

# %%
# modified from https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files
class DentalElementDataset(Dataset):
    def __init__(self, annotations_file, img_dir):
        with open(os.path.join(img_dir, annotations_file)) as label_file:
            labels = label_file.readlines()
        self.img_labels = pd.Series(labels)
        self.img_dir = img_dir
        self.transform = lambda image: processor(images=image, return_tensors="pt").pixel_values
        self.target_transform = lambda image: processor(images=image, return_tensors="pt").pixel_values 

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, f"{idx}.png")
        image = read_image(img_path)
        label = self.img_labels.iloc[idx]
        sample= self.transform(image)

        return sample, label

# %%
dental_data = DentalElementDataset(label_filename, path)
train_loader = torch.utils.data.DataLoader(dental_data, batch_size=4, shuffle=True)

# %% [markdown]
# ### Sanity check: print image & corresponding label

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images[0])
# matplotlib_imshow(img_grid, one_channel=True)

npimg = img_grid.numpy()
print(labels[0])
plt.axis('off')
plt.imshow(np.transpose(npimg, (1, 2, 0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Distal left humerus frag

# %% [markdown]
# ### Create character to unicode code point a & unicode code point to character functions
#
# Cross-entropy loss needs predictions and ground truths to be tensors -> convert characters to 1d tensors of code points
#
# Labels need to be equal in length with cross-entropy loss! Put some upper limit to character generation & set that as label length
# append 0's to get equal-length labels

# %%
test_labels = labels[:10]
test_label = labels[2]
print(test_label)

unicode_ids = [ord(char) for char in test_label]
print(unicode_ids)
and_back = [chr(uid) for uid in unicode_ids]
print(''.join(and_back))
# Out:
# A= R mandible with M2̄̌-̌3̄̌ M1̌ root
#
# [65, 61, 32, 82, 32, 109, 97, 110, 100, 105, 98, 108, 101, 32, 119, 105, 116, 104, 32, 77, 50, 772, 780, 45, 780, 51, 772, 780, 32, 77, 49, 780, 32, 114, 111, 111, 116, 10]
# A= R mandible with M2̄̌-̌3̄̌ M1̌ root

# %%
# output: 2d tensor, each row is one sequence -> 2d tensor is batch labels
def string_to_code_point_tensor(sequences):
    # but: what if labels are of different lengths?? add 0's to the back? this would not be necessary with ctc loss
    tensor_rows = [] 
    for sequence in sequences:
        tensor_rows.append(torch.tensor([ord(char) for char in sequence]))
    return torch.stack(tensor_rows, dim=0)

# input: 2d tensor, each row is one sequence -> 2d tensor is batch labels
def code_point_tensors_to_string(point_tensors):
    return ''.join([chr(uid) for uid in point_tensor])

print(string_to_code_point_tensor(test_labels))
print(code_point_tensor_to_string(string_to_code_point_tensor(test_label)))
print(list(map(string_to_code_point_tensor, test_labels)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 13
#      10 def code_point_tensors_to_string(point_tensors):
#      11     return ''.join([chr(uid) for uid in point_tensor])
# ---> 13 print(string_to_code_point_tensor(test_labels))
#      14 print(code_point_tensor_to_string(string_to_code_point_tensor(test_label)))
#      15 print(list(map(string_to_code_point_tensor, test_labels)))
#
# Cell In[36], line 7, in string_to_code_point_tensor(sequences)
#       5 for sequence in sequences:
#       6     tensor_rows.append(torch.tensor([ord(char) for char in sequence]))
# ----> 7 return torch.stack(tensor_rows, dim=0)
#
# RuntimeError: stack expects each tensor to be equal size, but got [26] at entry 0 and [40] at entry 1

# %% [markdown]
# ### Define hyperparameters
#
# current: from pytorch tutorial https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html

# %%
print(type(model)) # vision encoder decoder model
print(isinstance(model, nn.Module)) # is a torch neural network
print(type(processor)) # trocrprocessor, what is this?
print(isinstance(processor, nn.Module)) # not a neural network
print(type(processor).__mro__)
# Out:
# <class 'transformers.models.vision_encoder_decoder.modeling_vision_encoder_decoder.VisionEncoderDecoderModel'>
# True
# <class 'transformers.models.trocr.processing_trocr.TrOCRProcessor'>
# False
# (<class 'transformers.models.trocr.processing_trocr.TrOCRProcessor'>, <class 'transformers.processing_utils.ProcessorMixin'>, <class 'transformers.utils.hub.PushToHubMixin'>, <class 'object'>)

# %%
learning_rate = 1e-3
batch_size = 4
epochs = 5
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# from https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
# next: pred and y should be tensors not strings. option: convert to unicode ids. better: see trocr repo for their implementation.
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        generated_ids = model.generate(X)
        pred = processor.batch_decode(generated_ids, skip_special_tokens=True)
        loss = loss_fn(string_to_code_point_tensor(pred), string_to_code_point_tensor(y))

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        loss = loss.item()
        print(f"loss: {loss:>7f}")


def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pixels = processor(images=X, return_tensors="pt").pixel_values
            pred = model.generate(pixels)
            test_loss += loss_fn(string_to_code_point_tensor(pred), string_to_code_point_tensor(y)).item()
            # correct += (pred.argmax(1) == y).type(torch.float).sum().item() use f1 instead of this

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader, model, loss_fn, optimizer)
    test_loop(train_loader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 3
#       1 for t in range(epochs):
#       2     print(f"Epoch {t+1}\n-------------------------------")
# ----> 3     train_loop(train_loader, model, loss_fn, optimizer)
#       4     test_loop(train_loader, model, loss_fn)
#       5 print("Done!")
#
# Cell In[49], line 9, in train_loop(dataloader, model, loss_fn, optimizer)
#       6 model.train()
#       7 for batch, (X, y) in enumerate(dataloader):
#       8     # Compute prediction and loss
# ----> 9     generated_ids = model.generate(X)
#      10     pred = processor.batch_decode(generated_ids, skip_special_tokens=True)
#      11     loss = loss_fn(string_to_code_point_tensor(pred), string_to_code_point_tensor(y))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1492, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1484         logger.warning(
#    1485             "A decoder-only architecture is being used, but right-padding was detected! For correct "
#    1486             "generation results, please set `padding_side='left'` when initializing the tokenizer."
#    1487         )
#    1489 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1490     # if model is encoder decoder encoder_outputs are created
#    1491     # and added to `model_kwargs`
# -> 1492     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1493         inputs_tensor, model_kwargs, model_input_name
#    1494     )
#    1496 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1497 if self.config.is_encoder_decoder:
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:661, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     659 encoder_kwargs["return_dict"] = True
#     660 encoder_kwargs[model_input_name] = inputs_tensor
# --> 661 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     663 return model_kwargs
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:583, in ViTModel.forward(self, pixel_values, bool_masked_pos, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     580 if pixel_values.dtype != expected_dtype:
#     581     pixel_values = pixel_values.to(expected_dtype)
# --> 583 embedding_output = self.embeddings(
#     584     pixel_values, bool_masked_pos=bool_masked_pos, interpolate_pos_encoding=interpolate_pos_encoding
#     585 )
#     587 encoder_outputs = self.encoder(
#     588     embedding_output,
#     589     head_mask=head_mask,
#    (...)
#     592     return_dict=return_dict,
#     593 )
#     594 sequence_output = encoder_outputs[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:121, in ViTEmbeddings.forward(self, pixel_values, bool_masked_pos, interpolate_pos_encoding)
#     115 def forward(
#     116     self,
#     117     pixel_values: torch.Tensor,
#     118     bool_masked_pos: Optional[torch.BoolTensor] = None,
#     119     interpolate_pos_encoding: bool = False,
#     120 ) -> torch.Tensor:
# --> 121     batch_size, num_channels, height, width = pixel_values.shape
#     122     embeddings = self.patch_embeddings(pixel_values, interpolate_pos_encoding=interpolate_pos_encoding)
#     124     if bool_masked_pos is not None:
#
# ValueError: too many values to unpack (expected 4)
